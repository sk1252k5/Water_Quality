# %%
import sys
import os

# Adds the parent directory to the system path
sys.path.append(os.path.abspath(os.path.join('..')))

from src.model_recommendation import generate_recommendation

# %%
from src.model_recommendation import generate_recommendation

sample = {
    "ph": 7.2,
    "Hardness": 200,
    "Solids": 650,
    "Chloramines": 7,
    "Sulfate": 300,
    "Conductivity": 500,
    "Organic_carbon": 12,
    "Trihalomethanes": 70,
    "Turbidity": 6
}

result = generate_recommendation(sample)
print(result)
# Out:
# {'Potability_Prediction': 'Unsafe', 'Probability': 0.38336239673639033, 'Recommended_Treatment': 'RO Filtration + Sediment Filter + UV Purification'}
# c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join('..')))

from src.image_inference import analyze_water_image

result = analyze_water_image(r"D:\Water_Quality\notebooks\test_image_1.jpg")
print(result)
# Out:
# {'Predicted_Class': 'Bersih', 'Water_Quality': 'Clean', 'Recommendation': 'Safe to drink'}

# %%
model = models.mobilenet_v2(pretrained=False)
model.classifier[1] = nn.Linear(model.last_channel, 3)
model.load_state_dict(torch.load(r'D:\Water_Quality\models\water_cnn_model.pth', map_location=device))
model.to(device)
model.eval()
# Out:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# MobileNetV2(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
# ...

# %%
import torch
import torch.nn as nn
from torchvision import transforms, models
from PIL import Image

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

class_names = ['Bersih', 'Keruh', 'Kotor']

image_path = r'D:\Water_Quality\notebooks\test_image_2.jpg'
image = Image.open(image_path).convert("RGB")
image_tensor = transform(image).unsqueeze(0).to(device)

with torch.no_grad():
    outputs = model(image_tensor)
    probs = torch.softmax(outputs, dim=1)
    print(dict(zip(class_names, probs[0].tolist())))
# Out:
# {'Bersih': 0.6091030240058899, 'Keruh': 0.1616518348455429, 'Kotor': 0.2292451411485672}
